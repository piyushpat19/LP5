# %%
import sys 
print(sys.executable) 
import tensorflow as tf 
print(tf.__version__)
# Out:
# C:\Users\Patil\anaconda3\anac\python.exe
# 2.21.0

# %%
from tensorflow.keras.datasets import imdb

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
train_data[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  2,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  2,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  2,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  2,
#  8,
#  4,
#  107,
#  117,
#  5952,
#  15,
#  256,
#  4,
#  2,
#  7,
#  3766,
#  5,
#  723,
#  36,
#  71,
#  43,
#  530,
#  476,
#  26,
#  400,
#  317,
#  46,
#  7,
#  4,
#  2,
#  1029,
#  13,
#  104,
#  88,
#  4,
#  381,
#  15,
#  297,
#  98,
#  32,
#  2071,
#  56,
#  26,
#  141,
#  6,
#  194,
#  7486,
#  18,
#  4,
#  226,
#  22,
#  21,
#  134,
#  476,
#  26,
#  480,
#  5,
#  144,
#  30,
#  5535,
#  18,
#  51,
#  36,
#  28,
#  224,
#  92,
#  25,
#  104,
#  4,
#  226,
#  65,
#  16,
#  38,
#  1334,
#  88,
#  12,
#  16,
#  283,
#  5,
#  16,
#  4472,
#  113,
#  103,
#  32,
#  15,
#  16,
#  5345,
#  19,
#  178,
#  32]

# %%
train_labels[0]
# Out:
# 1

# %%
print(type([max(sequence) for sequence in train_data])) 
max([max(sequence) for sequence in train_data])
# Out:
# <class 'list'>
# 9999

# %%
import ssl 
ssl._create_default_https_context = ssl._create_unverified_context 
word_index = imdb.get_word_index() 
reverse_word_index = dict([(value, key) for (key, value) in 
word_index.items()]) 
decoded_review = ' '.join([reverse_word_index.get(i-3, '?') for i in 
train_data[0]]) 
decoded_review
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1641221/1641221 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# "? this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert ? is an amazing actor and now the same being director ? father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for ? and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also ? to the two little boy's that played the ? of norman and paul they were just brilliant children are often left out of the ? list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all"

# %%
len(reverse_word_index)
# Out:
# 88584

# %%
import numpy as np 
def vectorize_sequences(sequences, dimension = 10000): 
    results = np.zeros((len(sequences),dimension)) 
    for i,sequence in enumerate(sequences): 
        results[i,sequence] = 1 
    return results

# %%
 
xtrain = vectorize_sequences(train_data) 
xtest = vectorize_sequences(test_data) 
xtrain[0]
# Out:
# array([0., 1., 1., ..., 0., 0., 0.])

# %%
xtrain.shape
# Out:
# (25000, 10000)

# %%
ytrain = np.asarray(train_labels).astype('float32') 
ytest = np.asarray(test_labels).astype('float32') 
from tensorflow.keras import models 
from tensorflow.keras import layers

# %%
 
model = models.Sequential()

# Add Input layer first
model.add(layers.Input(shape=(10000,)))

model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras import metrics

# %%
 
model.compile(optimizer= optimizers.RMSprop(learning_rate= 0.001), 
              loss = losses.binary_crossentropy, 
              metrics= [metrics.binary_accuracy])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
xval = xtrain[:10000] 
partial_xtrain = xtrain[10000:] 
 
yval = ytrain[:10000] 
partial_ytrain = ytrain[10000:] 
history = model.fit(partial_xtrain, 
                    partial_ytrain, 
                    epochs=20, 
                    batch_size= 512, 
                    validation_data=(xval, yval))
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 230ms/step - binary_accuracy: 0.7825 - loss: 0.5256 - val_binary_accuracy: 0.8626 - val_loss: 0.3993
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - binary_accuracy: 0.8939 - loss: 0.3252 - val_binary_accuracy: 0.8806 - val_loss: 0.3170
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - binary_accuracy: 0.9184 - loss: 0.2439 - val_binary_accuracy: 0.8891 - val_loss: 0.2865
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - binary_accuracy: 0.9358 - loss: 0.1971 - val_binary_accuracy: 0.8819 - val_loss: 0.2930
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - binary_accuracy: 0.9453 - loss: 0.1660 - val_binary_accuracy: 0.8745 - val_loss: 0.3091
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - binary_accuracy: 0.9565 - loss: 0.1386 - val_binary_accuracy: 0.8857 - val_loss: 0.2967
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - binary_accuracy: 0.9598 - loss: 0.1237 - val_binary_accuracy: 0.8866 - val_loss: 0.2958
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - binary_accuracy: 0.9693 - loss: 0.1035 - val_binary_accuracy: 0.8842 - val_loss: 0.3152
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - binary_accuracy: 0.9749 - loss: 0.0888 - val_binary_accuracy: 0.8825 - val_loss: 0.3233
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - binary_accuracy: 0.9805 - loss: 0.0745 - val_binary_accuracy: 0.8716 - val_loss: 0.3637
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - binary_accuracy: 0.9850 - loss: 0.0618 - val_binary_accuracy: 0.8803 - val_loss: 0.3623
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - binary_accuracy: 0.9867 - loss: 0.0538 - val_binary_accuracy: 0.8743 - val_loss: 0.4092
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - binary_accuracy: 0.9905 - loss: 0.0450 - val_binary_accuracy: 0.8706 - val_loss: 0.4398
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - binary_accuracy: 0.9924 - loss: 0.0377 - val_binary_accuracy: 0.8745 - val_loss: 0.4264
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - binary_accuracy: 0.9939 - loss: 0.0316 - val_binary_accuracy: 0.8706 - val_loss: 0.4530
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - binary_accuracy: 0.9958 - loss: 0.0260 - val_binary_accuracy: 0.8709 - val_loss: 0.4949
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - binary_accuracy: 0.9956 - loss: 0.0244 - val_binary_accuracy: 0.8724 - val_loss: 0.4916
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - binary_accuracy: 0.9974 - loss: 0.0195 - val_binary_accuracy: 0.8706 - val_loss: 0.5158
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - binary_accuracy: 0.9969 - loss: 0.0181 - val_binary_accuracy: 0.8710 - val_loss: 0.5374
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - binary_accuracy: 0.9996 - loss: 0.0102 - val_binary_accuracy: 0.8699 - val_loss: 0.5605

# %%
history_dict = history.history 
history_dict.keys()
# Out:
# dict_keys(['binary_accuracy', 'loss', 'val_binary_accuracy', 'val_loss'])

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline 
loss_values = history_dict['loss'] 
val_loss_values = history_dict['val_loss'] 
 
epochs = range(1, len(loss_values)+1)

# %%
 
plt.plot(epochs, loss_values, 'bo', label = "Training Loss") 
plt.plot(epochs, val_loss_values, 'b', label = "Validation Loss") 
 
plt.title('Training and Validation Loss') 
plt.xlabel('Epochs') 
plt.ylabel('Loss Value') 
plt.legend() 
 
plt.show()

# %%
acc_values = history_dict['binary_accuracy'] 
val_acc_values = history_dict['val_binary_accuracy'] 
epochs = range(1, len(loss_values)+1)

# %%
plt.plot(epochs, acc_values, 'ro', label = "Training Accuracy") 
plt.plot(epochs, val_acc_values, 'r', label = "Validation Accuracy") 
plt.title('Training and Validation Accuracy') 
plt.xlabel('Epochs') 
plt.ylabel('Accuracy') 
plt.legend() 
plt.show()

# %%
model.fit(partial_xtrain, 
partial_ytrain, 
epochs= 3, 
batch_size= 512, 
validation_data=(xval,yval))
# Out:
# Epoch 1/3
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - binary_accuracy: 0.9982 - loss: 0.0126 - val_binary_accuracy: 0.8671 - val_loss: 0.5921
# Epoch 2/3
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - binary_accuracy: 0.9984 - loss: 0.0110 - val_binary_accuracy: 0.8707 - val_loss: 0.6175
# Epoch 3/3
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - binary_accuracy: 0.9999 - loss: 0.0058 - val_binary_accuracy: 0.8664 - val_loss: 0.6366
